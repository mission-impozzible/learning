# %% [markdown]
# <a href="https://colab.research.google.com/github/mission-impozzible/learning/blob/main/book_review/20260108_AI_engineering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AI Engineering

# %% [markdown]
# ## 1 - Introduction to building application with foundation models

# %% [markdown]
# ## 2 - Understanding foundation models
